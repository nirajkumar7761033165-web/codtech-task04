# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
url = "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv"
df = pd.read_csv(url, sep='\t', header=None, names=['label', 'message'])
df['label_num'] = df.label.map({'ham': 0, 'spam': 1})
print(df.head())
# Out:
#   label                                            message  label_num
# 0   ham  Go until jurong point, crazy.. Available only ...          0
# 1   ham                      Ok lar... Joking wif u oni...          0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3   ham  U dun say so early hor... U c already then say...          0
# 4   ham  Nah I don't think he goes to usf, he lives aro...          0

# %%
X_train, X_test, y_train, y_test = train_test_split(df['message'], df['label_num'], test_size=0.2, random_state=42)
print("Data train aur test ke liye split ho gaya hai!")
# Out:
# Data train aur test ke liye split ho gaya hai!

# %%
vectorizer = CountVectorizer()
X_train_dtm = vectorizer.fit_transform(X_train)

model = MultinomialNB()
model.fit(X_train_dtm, y_train)
print("Spam classifier model train ho gaya hai!")
# Out:
# Spam classifier model train ho gaya hai!

# %%
X_test_dtm = vectorizer.transform(X_test)
y_prediction = model.predict(X_test_dtm)
accuracy = accuracy_score(y_test, y_prediction)
print(f"Model ki Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model ki Accuracy: 99.19%
